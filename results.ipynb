# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

from src.pbn_gen import PbnGen

# %%
pbn = PbnGen("images/red_panda.jpg")
colors, labels, q_img = pbn.cluster_colors()
# Out:
# Quantized to 14 colors

# %%
plt.imshow(pbn.image)

# %%
# make sure to run cluster colors first
pbn.plt_cluster_pie()

# %%
plt.imshow(q_img)

# %%
pbn = PbnGen("images/red_panda.jpg", num_colors=10)
colors, labels, q_img = pbn.cluster_colors()
# Out:
# Quantized to 10 colors

# %%
pbn.plt_cluster_pie()

# %%
plt.imshow(q_img)
